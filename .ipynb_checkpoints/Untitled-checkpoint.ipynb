# %%
# !pip install --upgrade pip

# !pip install \
opencv-python \
mediapipe \
tensorflow \
deepface \
ultralytics \
fastapi \
uvicorn \
pymongo \
python-dotenv \
loguru \
pyyaml \
pytest \
scikit-learn \
matplotlib \
pandas \
numpy \
jupyterlab

# %%
# !pip install opencv-python mediapipe tensorflow deepface ultralytics fastapi uvicorn pymongo python-dotenv loguru pyyaml pytest scikit-learn matplotlib pandas numpy

# %%
import cv2
import mediapipe as mp
import tensorflow as tf
from deepface import DeepFace
from ultralytics import YOLO
import fastapi
import pymongo
import dotenv
import loguru
import yaml
import pytest
import sklearn
import matplotlib
import pandas as pd
import numpy as np

print("="*60)
print("🎉 ALL REQUIRED LIBRARIES ARE INSTALLED SUCCESSFULLY!")
print("="*60)

print(f"OpenCV Version      : {cv2.__version__}")
print(f"TensorFlow Version  : {tf.__version__}")
print(f"Pandas Version      : {pd.__version__}")
print(f"NumPy Version       : {np.__version__}")
print(f"Matplotlib Version  : {matplotlib.__version__}")
print(f"Scikit-learn Version: {sklearn.__version__}")
print(f"FastAPI Version     : {fastapi.__version__}")
print(f"PyMongo Version     : {pymongo.version}")
print("="*60)

# %%
# !pip install tf-keras

# %%
from deepface import DeepFace
print("✅ DeepFace imported successfully!")
# Out:
# WARNING:tensorflow:From C:\Users\disha\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 26-07-09 13:09:25 - Directory C:\Users\disha\.deepface has been created
# 26-07-09 13:09:25 - Directory C:\Users\disha\.deepface\weights has been created
# ✅ DeepFace imported successfully!

# %%
import cv2
import mediapipe as mp
import tensorflow as tf
from deepface import DeepFace
from ultralytics import YOLO
import fastapi
import pymongo
import pandas as pd
import numpy as np
import sklearn
import matplotlib

print("🎉 ALL REQUIRED LIBRARIES ARE INSTALLED SUCCESSFULLY!")

print("OpenCV:", cv2.__version__)
print("TensorFlow:", tf.__version__)
print("MediaPipe:", mp.__version__)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("FastAPI:", fastapi.__version__)
print("PyMongo:", pymongo.version)
print("Scikit-learn:", sklearn.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\disha\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 🎉 ALL REQUIRED LIBRARIES ARE INSTALLED SUCCESSFULLY!
# OpenCV: 5.0.0
# TensorFlow: 2.21.0
# MediaPipe: 0.10.35
# Pandas: 2.3.3
# NumPy: 2.3.5
# FastAPI: 0.139.0
# PyMongo: 4.17.0
# Scikit-learn: 1.7.2

# %%
# !pip install motor

# %%
from motor.motor_asyncio import AsyncIOMotorClient

print("Motor installed successfully")
# Out:
# Motor installed successfully

# %%
# !pip install motor
