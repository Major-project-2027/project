# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\disha\anaconda3\lib\site-packages (0.10.35)
# Requirement already satisfied: absl-py~=2.3 in c:\users\disha\anaconda3\lib\site-packages (from mediapipe) (2.5.0)
# Requirement already satisfied: certifi in c:\users\disha\anaconda3\lib\site-packages (from mediapipe) (2026.1.4)
# Requirement already satisfied: numpy in c:\users\disha\anaconda3\lib\site-packages (from mediapipe) (2.3.5)
# Requirement already satisfied: sounddevice~=0.5 in c:\users\disha\anaconda3\lib\site-packages (from mediapipe) (0.5.5)
# Requirement already satisfied: flatbuffers~=25.9 in c:\users\disha\anaconda3\lib\site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in c:\users\disha\anaconda3\lib\site-packages (from mediapipe) (5.0.0.93)
# Requirement already satisfied: matplotlib in c:\users\disha\anaconda3\lib\site-packages (from mediapipe) (3.10.6)
# Requirement already satisfied: cffi in c:\users\disha\anaconda3\lib\site-packages (from sounddevice~=0.5->mediapipe) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\disha\anaconda3\lib\site-packages (from cffi->sounddevice~=0.5->mediapipe) (2.23)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\disha\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\disha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
import cv2
import mediapipe as mp
import numpy as np

print("OpenCV:", cv2.__version__)
print("MediaPipe Installed Successfully")
# Out:
# OpenCV: 5.0.0
# MediaPipe Installed Successfully

# %%
import mediapipe as mp

mp_face_mesh = mp.solutions.face_mesh

face_mesh = mp_face_mesh.FaceMesh(
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

print("Face Mesh Ready")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import mediapipe as mp
# ----> 3 mp_face_mesh = mp.solutions.face_mesh
#       5 face_mesh = mp_face_mesh.FaceMesh(
#       6     max_num_faces=1,
#       7     refine_landmarks=True,
#       8     min_detection_confidence=0.5,
#       9     min_tracking_confidence=0.5
#      10 )
#      12 print("Face Mesh Ready")
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
import mediapipe as mp

print(mp)
print(mp.__file__)
# Out:
# <module 'mediapipe' from 'C:\\Users\\disha\\anaconda3\\Lib\\site-packages\\mediapipe\\__init__.py'>
# C:\Users\disha\anaconda3\Lib\site-packages\mediapipe\__init__.py

# %%
import mediapipe as mp

print(mp.__version__)
# Out:
# 0.10.35

# %%
import mediapipe as mp

print("Version:", mp.__version__)
print("Has solutions:", hasattr(mp, "solutions"))
print(dir(mp))
# Out:
# Version: 0.10.35
# Has solutions: False
# ['Image', 'ImageFormat', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'tasks']

# %%
pip uninstall mediapipe
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import face_recognition
print("Face Recognition Installed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import face_recognition
#       2 print("Face Recognition Installed")
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
import cv2

print(cv2.__version__)
print(hasattr(cv2, "face"))
# Out:
# 5.0.0
# True
