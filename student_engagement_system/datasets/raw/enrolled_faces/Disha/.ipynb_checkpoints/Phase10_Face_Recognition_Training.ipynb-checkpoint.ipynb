# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.21.0

# %%
IMG_SIZE = (160, 160)
BATCH_SIZE = 16

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.15,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    "datasets/raw/enrolled_faces",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training",
    shuffle=True
)

val_generator = train_datagen.flow_from_directory(
    "datasets/raw/enrolled_faces",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation",
    shuffle=False
)

print("\nClasses:")
print(train_generator.class_indices)

print("\nTraining Images:", train_generator.samples)
print("Validation Images:", val_generator.samples)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 12
#       8     zoom_range=0.15,
#       9     horizontal_flip=True
#      10 )
#      11
# ---> 12 train_generator = train_datagen.flow_from_directory(
#      13     "datasets/raw/enrolled_faces",
#      14     target_size=IMG_SIZE,
#      15     batch_size=BATCH_SIZE,
#
# File ~\anaconda3\envs\engagement\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1137, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1119 def flow_from_directory(
#    1120     self,
#    1121     directory,
#    (...)   1135     keep_aspect_ratio=False,
#    1136 ):
# -> 1137     return DirectoryIterator(
#    1138         directory,
#    1139         self,
#    1140         target_size=target_size,
#    1141         color_mode=color_mode,
#    1142         keep_aspect_ratio=keep_aspect_ratio,
#    1143         classes=classes,
#    1144         class_mode=class_mode,
#    1145         data_format=self.data_format,
#    1146         batch_size=batch_size,
#    1147         shuffle=shuffle,
#    1148         seed=seed,
#    1149         save_to_dir=save_to_dir,
#    1150         save_prefix=save_prefix,
#    1151         save_format=save_format,
#    1152         follow_links=follow_links,
#    1153         subset=subset,
#    1154         interpolation=interpolation,
#    1155         dtype=self.dtype,
#    1156     )
#
# File ~\anaconda3\envs\engagement\Lib\site-packages\keras\src\legacy\preprocessing\image.py:457, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     455 if not classes:
#     456     classes = []
# --> 457     for subdir in sorted(os.listdir(directory)):
#     458         if os.path.isdir(os.path.join(directory, subdir)):
#     459             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'datasets/raw/enrolled_faces'

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\disha\Predictive_Multimodal_Student_Engagement\student_engagement_system\datasets\raw\enrolled_faces\Disha

# %%
import os

print(os.listdir(r"C:\Users\disha\Predictive_Multimodal_Student_Engagement\student_engagement_system\datasets\raw\enrolled_faces"))
# Out:
# ['.gitkeep', 'Disha']
