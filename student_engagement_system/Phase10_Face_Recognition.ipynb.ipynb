# %%
import cv2
import os

SAVE_DIR = "datasets/raw/enrolled_faces/Disha"

os.makedirs(SAVE_DIR, exist_ok=True)

face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

cap = cv2.VideoCapture(0)

count = 0

print("Press 'q' to quit")

while True:
    ret, frame = cap.read()

    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_detector.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )

    for (x, y, w, h) in faces:

        face = gray[y:y+h, x:x+w]
        face = cv2.resize(face, (200, 200))

        cv2.imwrite(
            os.path.join(SAVE_DIR, f"{count}.jpg"),
            face
        )

        count += 1

        cv2.rectangle(frame,
                      (x, y),
                      (x+w, y+h),
                      (0,255,0),
                      2)

        cv2.putText(frame,
                    f"Captured: {count}",
                    (20,40),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    (0,255,0),
                    2)

    cv2.imshow("Capture Faces", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    if count >= 100:
        break

cap.release()
cv2.destroyAllWindows()

print("Finished Capturing!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       4 SAVE_DIR = "datasets/raw/enrolled_faces/Disha"
#       5
#       6 os.makedirs(SAVE_DIR, exist_ok=True)
#       7
# ----> 8 face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
#       9
#      10 cap = cv2.VideoCapture(0)
#      11
#
# AttributeError: module 'cv2' has no attribute 'CascadeClassifier'

# %%
import cv2

print(cv2)
print(cv2.__file__)
print(cv2.__version__)
print(dir(cv2)[:30])
# Out:
# <module 'cv2' from 'C:\\Users\\disha\\anaconda3\\envs\\engagement\\Lib\\site-packages\\cv2\\__init__.py'>
# C:\Users\disha\anaconda3\envs\engagement\Lib\site-packages\cv2\__init__.py
# 5.0.0
# ['ACCESS_FAST', 'ACCESS_MASK', 'ACCESS_READ', 'ACCESS_RW', 'ACCESS_WRITE', 'ADAPTIVE_THRESH_GAUSSIAN_C', 'ADAPTIVE_THRESH_MEAN_C', 'ALGO_HINT_ACCURATE', 'ALGO_HINT_APPROX', 'ALGO_HINT_DEFAULT', 'ALIKED', 'ALIKED_Params', 'ALIKED_create', 'ANNINDEX_DIST_ANGULAR', 'ANNINDEX_DIST_DOTPRODUCT', 'ANNINDEX_DIST_EUCLIDEAN', 'ANNINDEX_DIST_HAMMING', 'ANNINDEX_DIST_MANHATTAN', 'ANNIndex', 'ANNIndex_DIST_ANGULAR', 'ANNIndex_DIST_DOTPRODUCT', 'ANNIndex_DIST_EUCLIDEAN', 'ANNIndex_DIST_HAMMING', 'ANNIndex_DIST_MANHATTAN', 'ANNIndex_create', 'AffineFeature', 'AffineFeature_create', 'Algorithm', 'AlignExposures', 'AlignMTB']

# %%
import cv2

print("Cascade:", hasattr(cv2, "CascadeClassifier"))
print("VideoCapture:", hasattr(cv2, "VideoCapture"))
print("imshow:", hasattr(cv2, "imshow"))
# Out:
# Cascade: False
# VideoCapture: True
# imshow: True

# %%
import cv2

print(cv2.__version__)
print(hasattr(cv2, "CascadeClassifier"))
print(hasattr(cv2, "VideoCapture"))
# Out:
# 4.10.0
# True
# True

# %%
import os
import cv2

# Folder to save your face images
SAVE_DIR = "datasets/raw/enrolled_faces/Disha"
os.makedirs(SAVE_DIR, exist_ok=True)

# Load face detector
face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# Open webcam
cap = cv2.VideoCapture(0)

count = 0

print("Press 'q' to quit.")

while True:
    ret, frame = cap.read()

    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_detector.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )

    for (x, y, w, h) in faces:

        face = gray[y:y+h, x:x+w]
        face = cv2.resize(face, (160, 160))

        filename = os.path.join(SAVE_DIR, f"face_{count}.jpg")
        cv2.imwrite(filename, face)

        count += 1

        cv2.rectangle(frame, (x, y), (x+w, y+h), (0,255,0), 2)
        cv2.putText(frame, f"Images: {count}", (10,30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)

    cv2.imshow("Capture Faces", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

    if count >= 100:
        break

cap.release()
cv2.destroyAllWindows()

print("Finished Capturing!")
# Out:
# Press 'q' to quit.
# Finished Capturing!

# %%
import cv2

cap = cv2.VideoCapture(0)

print(cap.isOpened())

ret, frame = cap.read()
print(ret)

cap.release()
# Out:
# True
# True

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        print("Camera not working")
        break

    cv2.imshow("Camera Test", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_detector.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )

    print("Faces:", len(faces))

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0,255,0), 2)

    cv2.imshow("Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 0
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 0
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 0
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 0
# Faces: 0
# Faces: 1
# Faces: 1
# Faces: 0
# Faces: 0
# Faces: 0
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1
# Faces: 1

# %%
import cv2
import os

SAVE_DIR = "datasets/raw/enrolled_faces/Disha"
os.makedirs(SAVE_DIR, exist_ok=True)

face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

cap = cv2.VideoCapture(0)

count = 0

print("Press 'q' to quit.")

while True:

    ret, frame = cap.read()

    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_detector.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )

    for (x, y, w, h) in faces:

        face = gray[y:y+h, x:x+w]

        face = cv2.resize(face, (160,160))

        filename = os.path.join(SAVE_DIR, f"{count}.jpg")

        cv2.imwrite(filename, face)

        count += 1

        cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,0), 2)

        cv2.putText(
            frame,
            f"Images: {count}",
            (10,30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0,255,0),
            2
        )

        if count >= 100:
            break

    cv2.imshow("Capture Faces", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    if count >= 100:
        break

cap.release()
cv2.destroyAllWindows()

print("Finished Capturing!")
print("Images saved:", count)
# Out:
# Press 'q' to quit.
# Finished Capturing!
# Images saved: 100
