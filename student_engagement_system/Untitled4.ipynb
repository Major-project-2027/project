# %%
import sys
print(sys.executable)
# Out:
# C:\Users\disha\anaconda3\envs\engagement2\python.exe

# %%
import loguru
print("LOGURU OK")
# Out:
# LOGURU OK

# %%
from ml_models.face_authentication.attendance_manager import AttendanceManager

print("ATTENDANCE MANAGER IMPORT SUCCESS")
# Out:
# ATTENDANCE MANAGER IMPORT SUCCESS
